# %%
# 3:58pm

import os
from PIL import Image
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import cv2
parent_list = os.listdir("./Small_Galaxy_Zoo/")
parent_list.sort()
count =0
for child in parent_list:
   if count < 10:
      print(child)
   else:
       break
   count = count+1
# Out:
# 100008.jpg
# 100023.jpg
# 100053.jpg
# 100078.jpg
# 100090.jpg
# 100122.jpg
# 100123.jpg
# 100128.jpg
# 100134.jpg
# 100143.jpg

# %%
for child in parent_list:
    if count < 20:
        print(child)
        img = Image.open("./Small_Galaxy_Zoo/" + child).convert("RGB")
        plt.imshow(img)
        plt.show()
    else:
        break
    count = count+1
# Out:
# 100008.jpg
# 100023.jpg
# 100053.jpg
# 100078.jpg
# 100090.jpg
# 100122.jpg
# 100123.jpg
# 100128.jpg
# 100134.jpg
# 100143.jpg
